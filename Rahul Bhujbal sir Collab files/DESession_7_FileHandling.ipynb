# %%
# File Type
# Text File - All programe/text files are text file
# Binary File - Images, Videos, music etc

# How file I/O done in most programming language
  # Open
  # Read/Write
  # close the file

# %%
# Write a file
# Case- if the file is not present
f = open('sample.txt','w')
f.write('Hello World')
f.close()

# %%
f = open('sample_1.txt','w')
f.write('Hello World')
f.close()
f.write('Hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1845/777691693.py in <cell line: 0>()
#       2 f.write('Hello World')
#       3 f.close()
# ----> 4 f.write('Hi')
#
# ValueError: I/O operation on closed file.

# %%
f = open('sample_2.txt','w')
f.write('Hello World')

f.write('Hi')
f.close()

# %%
f = open('sample_3.txt','w')
f.write('Hello World')

f.write('\nHi')
f.close()

# %%
f = open('sample.txt','w')
f.write('File handling is most IMP')
f.close()

# %%
f = open('sample.txt','a')
f.write('Hello world')
f.write('\nHi')
f.write('\nGood Afternoon')
f.close()

# %%
L = ['hello\n','hi\n','how are you\n','I am fine']
f = open('sample_4.txt','w')
f.writelines(L)
f.close()

# %%
L = ['hello','hi','how are you','I am fine']
f = open('sample_5.txt','w')
f.writelines(L)
f.close()

# %%
# reading from file
f = open('sample_4.txt','r')
data = f.read()
print(data)
f.close()
#
# Out:
# hello
# hi
# how are you
# I am fine

# %%
f = open('sample_4.txt','r')
data = f.read(5)
print(data)
f.close()
# Out:
# hello

# %%
f = open('sample_4.txt','r')
data = f.readline()
print(data)
data = f.readline()
print(data)
f.close()
# Out:
# hello
#
# hi

# %%
f = open('sample_4.txt','r')
data = f.readlines()
print(data)

f.close()
# Out:
# ['hello\n', 'hi\n', 'how are you\n', 'I am fine']

# %%
f = open('sample_4.txt','r')

while f.readline() != '':
    print(f.readline())
f.close()
# Out:
# hi
#
# I am fine

# %%
f = open('sample_4.txt','r')
for line in f:
    print(line)
f.close()
# Out:
# hello
#
# hi
#
# how are you
#
# I am fine

# %%
# with
with open('sample_6.txt','w') as f:
    f.write('Hello World')

# %%
f.write('Hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10954/667462264.py in <cell line: 0>()
# ----> 1 f.write('Hi')
#
# ValueError: I/O operation on closed file.

# %%
with open('sample_6.txt','r') as f:
  print(f.read())
# Out:
# Hello World

# %%
with open('sample_6.txt','r') as f:
  print(f.read(4))
  print(f.read(6))
# Out:
# Hell
# o Worl

# %%
# using contaxt manager
 # its good idead to close a file after usage as it will freeup the resources

# %%
L = ['hello' for i in range(1000)]

with open('sample_7.txt','w') as f:
  f.writelines(L)

# %%
with open('sample_7.txt','r') as f:
  size = 12
  while len(f.read(size)) > 0:
    print(f.read(size))
    f.read(size)
# Out:
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# lohellohello
# ohellohelloh
# hellohellohe
# ellohellohel
# llohellohell
# ...

# %%
with open('image.png','rb') as f:
  with open('image_copy.png','wb') as wf:
    wf.write(f.read())

# %%
with open('integer','w') as f:
  f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10954/1683771917.py in <cell line: 0>()
#       1 with open('integer','w') as f:
# ----> 2   f.write(5)
#
# TypeError: write() argument must be str, not int

# %%
d = {
    'name':'Rahul',
    'age':36,
    'gender':'Male'
}

with open('sample_8.txt','w') as f:
  f.write(str(d))

# %%
d = {
    'name':'Rahul',
    'age':36,
    'gender':'Male'
}

with open('sample_8.txt','w') as f:
  f.write((d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10954/2847466471.py in <cell line: 0>()
#       6
#       7 with open('sample_8.txt','w') as f:
# ----> 8   f.write((d))
#
# TypeError: write() argument must be str, not dict

# %%
import json
L = [1,2,3,4]
with open('sample_9.json','w') as f:
  json.dump(L,f)

# %%
d = {
    'name':'Rahul',
    'age':36,
    'gender':'Male'
}

with open('sample_10.json','w') as f:
  json.dump(d,f)
